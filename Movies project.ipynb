# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
pd.set_option("display.max_columns", 30)
pd.set_option("display.float_format", "{:.2f}".format)

# %%
df= pd.read_csv("movies_complete.csv", parse_dates=["release_date"])

df
# Out:
#            id                        title  \
# 0         862                    Toy Story
# 1        8844                      Jumanji
# 2       15602             Grumpier Old Men
# 3       31357            Waiting to Exhale
# 4       11862  Father of the Bride Part II
# ...       ...                          ...
# 44686  439050                       Subdue
# 44687  111109          Century of Birthing
# 44688   67758                     Betrayal
# 44689  227506             Satan Triumphant
# 44690  461257                     Queerama
#
#                                                  tagline release_date  \
# 0                                                    NaN   1995-10-30
# 1              Roll the dice and unleash the excitement!   1995-12-15
# 2      Still Yelling. Still Fighting. Still Ready for...   1995-12-22
# 3      Friends are the people who let you be yourself...   1995-12-22
# 4      Just When His World Is Back To Normal... He's ...   1995-02-10
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 44691 entries, 0 to 44690
# Data columns (total 22 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id                     44691 non-null  int64
#  1   title                  44691 non-null  object
#  2   tagline                20284 non-null  object
#  3   release_date           44657 non-null  datetime64[ns]
#  4   genres                 42586 non-null  object
#  5   belongs_to_collection  4463 non-null   object
#  6   original_language      44681 non-null  object
#  7   budget_musd            8854 non-null   float64
#  8   revenue_musd           7385 non-null   float64
#  9   production_companies   33356 non-null  object
#  10  production_countries   38835 non-null  object
#  11  vote_count             44691 non-null  float64
#  12  vote_average           42077 non-null  float64
#  13  popularity             44691 non-null  float64
# ...

# %%
df.loc[1, "genres"] #or much easier df.genre[1]
# Out:
# 'Adventure|Fantasy|Family'

# %%
df.cast[1]
# Out:
# 'Robin Williams|Jonathan Hyde|Kirsten Dunst|Bradley Pierce|Bonnie Hunt|Bebe Neuwirth|David Alan Grier|Patricia Clarkson|Adam Hann-Byrd|Laura Bell Bundy|James Handy|Gillian Barber|Brandon Obray|Cyrus Thiedeke|Gary Joseph Thorup|Leonard Zola|Lloyd Berry|Malcolm Stewart|Annabel Kershaw|Darryl Henriques|Robyn Driscoll|Peter Bryant|Sarah Gilson|Florica Vlad|June Lion|Brenda Lockmuller'

# %%
df.describe()
# Out:
#              id                   release_date  budget_musd  revenue_musd  \
# count  44691.00                          44657      8854.00       7385.00
# mean  107186.24  1992-04-28 16:30:02.539355520        21.67         68.97
# min        2.00            1874-12-09 00:00:00         0.00          0.00
# 25%    26033.50            1978-08-12 00:00:00         2.00          2.41
# 50%    59110.00            2001-08-16 00:00:00         8.20         16.87
# 75%   154251.00            2010-12-10 00:00:00        25.00         67.64
# max   469172.00            2017-12-27 00:00:00       380.00       2787.97
# std   111806.36                            NaN        34.36        146.61
#
#        vote_count  vote_average  popularity  runtime  cast_size  crew_size
# count    44691.00      42077.00    44691.00 43179.00   44691.00   44691.00
# mean       111.65          6.00        2.96    97.57      12.48      10.31
# min          0.00          0.00        0.00     1.00       0.00       0.00
# ...

# %%
df.hist(figsize=(20,12), bins=100) #figsize(width,height), bins=number of blocks in the histogram -this determines the width of bin
plt.show() #this is all matplotlib

# %%
df["budget_musd"].value_counts(dropna=False).head(20)
# Out:
# budget_musd
# NaN      35837
# 5.00       286
# 10.00      258
# 20.00      243
# 2.00       241
# 15.00      226
# 3.00       220
# 25.00      206
# 1.00       195
# 30.00      189
# 4.00       180
# 6.00       173
# 12.00      171
# 40.00      166
# 8.00       155
# 35.00      141
# 0.50       141
# 7.00       137
# 50.00      124
# 1.50       119
# Name: count, dtype: int64

# %%
df["revenue_musd"].value_counts(dropna=False).head(20)
# Out:
# revenue_musd
# NaN      37306
# 12.00       20
# 10.00       19
# 11.00       19
# 2.00        18
# 6.00        17
# 5.00        14
# 0.50        13
# 8.00        13
# 0.00        12
# 14.00       12
# 7.00        11
# 3.00        10
# 1.00        10
# 20.00       10
# 0.00         9
# 1.50         9
# 4.00         9
# 30.00        8
# 4.10         8
# Name: count, dtype: int64

# %%
df.describe(include= "object")
# Out:
#              title                 tagline genres belongs_to_collection  \
# count        44691                   20284  42586                  4463
# unique       41605                   20171   4044                  1691
# top     Cinderella  Based on a true story.  Drama       The Bowery Boys
# freq            11                       7   4935                    29
#
#        original_language       production_companies      production_countries  \
# count              44681                      33356                     38835
# unique                89                      22537                      2377
# top                   en  Metro-Goldwyn-Mayer (MGM)  United States of America
# freq               31755                        741                     17723
#
#                                     overview spoken_languages  \
# count                                  43740            41094
# unique                                 43715             1828
# ...

# %%
df[df["title"] == "Cinderella"].loc[:, ["title", "id", "genres"]]
# Out:
#             title      id                                 genres
# 984    Cinderella   11224       Family|Fantasy|Animation|Romance
# 12988  Cinderella   42884  TV Movie|Family|Fantasy|Music|Romance
# 23254  Cinderella   92349                          Fantasy|Drama
# 23265  Cinderella  105875               Animation|Family|Fantasy
# 28073  Cinderella  261985                        Family|TV Movie
# 28340  Cinderella  150689           Romance|Fantasy|Family|Drama
# 33805  Cinderella   42651                  Comedy|Family|Fantasy
# 35114  Cinderella   44459                          Drama|Romance
# 35116  Cinderella  289673                                    NaN
# 40439  Cinderella  114108  Fantasy|Horror|Science Fiction|Family
# 44633  Cinderella   98604                         Comedy|Romance

# %% [markdown]
# ## Find the top 5 movies

# %%
from IPython.display import HTML

# %%
df_best = df[["poster_path", "title", "budget_musd", "revenue_musd", "vote_count", "vote_average", "popularity" ]].copy()

df_best
# Out:
#                                              poster_path  \
# 0      <img src='http://image.tmdb.org/t/p/w185//uXDf...
# 1      <img src='http://image.tmdb.org/t/p/w185//vgpX...
# 2      <img src='http://image.tmdb.org/t/p/w185//1FSX...
# 3      <img src='http://image.tmdb.org/t/p/w185//4wjG...
# 4      <img src='http://image.tmdb.org/t/p/w185//lf9R...
# ...                                                  ...
# 44686  <img src='http://image.tmdb.org/t/p/w185//pfC8...
# 44687  <img src='http://image.tmdb.org/t/p/w185//xZkm...
# 44688  <img src='http://image.tmdb.org/t/p/w185//eGga...
# 44689  <img src='http://image.tmdb.org/t/p/w185//aorB...
# 44690  <img src='http://image.tmdb.org/t/p/w185//oxFE...
#
#                              title  budget_musd  revenue_musd  vote_count  \
# 0                        Toy Story        30.00        373.55     5415.00
# 1                          Jumanji        65.00        262.80     2413.00
# ...

# %%
df_best["profit_musd"] = df["revenue_musd"].sub(df["budget_musd"])  # profit 
#df_best["ROI"] = df_best["revenue_musd"] /df_best[df_best.budget_musd >= 10]["budget_musd"] #roi
df_best["ROI"] = df["revenue_musd"]/(df["budget_musd"])

# %%
df_best
# Out:
#                                              poster_path  \
# 0      <img src='http://image.tmdb.org/t/p/w185//uXDf...
# 1      <img src='http://image.tmdb.org/t/p/w185//vgpX...
# 2      <img src='http://image.tmdb.org/t/p/w185//1FSX...
# 3      <img src='http://image.tmdb.org/t/p/w185//4wjG...
# 4      <img src='http://image.tmdb.org/t/p/w185//lf9R...
# ...                                                  ...
# 44686  <img src='http://image.tmdb.org/t/p/w185//pfC8...
# 44687  <img src='http://image.tmdb.org/t/p/w185//xZkm...
# 44688  <img src='http://image.tmdb.org/t/p/w185//eGga...
# 44689  <img src='http://image.tmdb.org/t/p/w185//aorB...
# 44690  <img src='http://image.tmdb.org/t/p/w185//oxFE...
#
#                              title  budget_musd  revenue_musd  vote_count  \
# 0                        Toy Story        30.00        373.55     5415.00
# 1                          Jumanji        65.00        262.80     2413.00
# ...

# %%
df_best.columns= ["", "Title", "Budget", "Revenue", "Votes", "Average Rating", "Popularity", "Profit", "ROI"]

df_best
# Out:
#                                                           \
# 0      <img src='http://image.tmdb.org/t/p/w185//uXDf...
# 1      <img src='http://image.tmdb.org/t/p/w185//vgpX...
# 2      <img src='http://image.tmdb.org/t/p/w185//1FSX...
# 3      <img src='http://image.tmdb.org/t/p/w185//4wjG...
# 4      <img src='http://image.tmdb.org/t/p/w185//lf9R...
# ...                                                  ...
# 44686  <img src='http://image.tmdb.org/t/p/w185//pfC8...
# 44687  <img src='http://image.tmdb.org/t/p/w185//xZkm...
# 44688  <img src='http://image.tmdb.org/t/p/w185//eGga...
# 44689  <img src='http://image.tmdb.org/t/p/w185//aorB...
# 44690  <img src='http://image.tmdb.org/t/p/w185//oxFE...
#
#                              Title  Budget  Revenue   Votes  Average Rating  \
# 0                        Toy Story   30.00   373.55 5415.00            7.70
# 1                          Jumanji   65.00   262.80 2413.00            6.90
# ...

# %%
df_best.set_index("Title", inplace=True) #inplace modifies the dataframe rather than creating a new one
df_best
# Out:
#                                                                                 \
# Title
# Toy Story                    <img src='http://image.tmdb.org/t/p/w185//uXDf...
# Jumanji                      <img src='http://image.tmdb.org/t/p/w185//vgpX...
# Grumpier Old Men             <img src='http://image.tmdb.org/t/p/w185//1FSX...
# Waiting to Exhale            <img src='http://image.tmdb.org/t/p/w185//4wjG...
# Father of the Bride Part II  <img src='http://image.tmdb.org/t/p/w185//lf9R...
# ...                                                                        ...
# Subdue                       <img src='http://image.tmdb.org/t/p/w185//pfC8...
# Century of Birthing          <img src='http://image.tmdb.org/t/p/w185//xZkm...
# Betrayal                     <img src='http://image.tmdb.org/t/p/w185//eGga...
# Satan Triumphant             <img src='http://image.tmdb.org/t/p/w185//aorB...
# Queerama                     <img src='http://image.tmdb.org/t/p/w185//oxFE...
#
# ...

# %%
df_best.loc[["Avatar", ]]
# Out:
#                                                            Budget  Revenue  \
# Title
# Avatar  <img src='http://image.tmdb.org/t/p/w185//btnl...  237.00  2787.97
#
#           Votes  Average Rating  Popularity  Profit   ROI
# Title
# Avatar 12114.00            7.20      185.07 2550.97 11.76

# %%
df_best.iloc[0,0]
# Out:
# "<img src='http://image.tmdb.org/t/p/w185//uXDfjJbdP4ijW5hWSBrPrlKpxab.jpg' style='height:100px;'>"

# %% [markdown]
# # Lets put the images inside the dataframe

# %%
subset = df_best.iloc[:5, :2]

subset
# Out:
#                                                                                 \
# Title
# Toy Story                    <img src='http://image.tmdb.org/t/p/w185//uXDf...
# Jumanji                      <img src='http://image.tmdb.org/t/p/w185//vgpX...
# Grumpier Old Men             <img src='http://image.tmdb.org/t/p/w185//1FSX...
# Waiting to Exhale            <img src='http://image.tmdb.org/t/p/w185//4wjG...
# Father of the Bride Part II  <img src='http://image.tmdb.org/t/p/w185//lf9R...
#
#                              Budget
# Title
# Toy Story                     30.00
# Jumanji                       65.00
# Grumpier Old Men                NaN
# Waiting to Exhale             16.00
# Father of the Bride Part II     NaN

# %%
HTML(subset.to_html(escape=False))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th></th>
#       <th>Budget</th>
#     </tr>
#     <tr>
#       <th>Title</th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Toy Story</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//uXDfjJbdP4ijW5hWSBrPrlKpxab.jpg' style='height:100px;'></td>
#       <td>30.00</td>
#     </tr>
#     <tr>
#       <th>Jumanji</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//vgpXmVaVyUL7GGiDeiK1mKEKzcX.jpg' style='height:100px;'></td>
#       <td>65.00</td>
#     </tr>
#     <tr>
#       <th>Grumpier Old Men</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//1FSXpj5e8l4KH6nVFO5SPUeraOt.jpg' style='height:100px;'></td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>Waiting to Exhale</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//4wjGMwPsdlvi025ZqR4rXnFDvBz.jpg' style='height:100px;'></td>
# ...

# %%
df_best.loc[df_best.Votes >= 10].sort_values(by= "Average Rating", ascending=False)
# Out:
#                                                                                                        \
# Title
# As I Was Moving Ahead Occasionally I Saw Brief ...  <img src='http://image.tmdb.org/t/p/w185//k0I6...
# Planet Earth II                                     <img src='http://image.tmdb.org/t/p/w185//gTvA...
# The Civil War                                       <img src='http://image.tmdb.org/t/p/w185//r4sW...
# Dilwale Dulhania Le Jayenge                         <img src='http://image.tmdb.org/t/p/w185//2CAL...
# Cosmos                                              <img src='http://image.tmdb.org/t/p/w185//mYrn...
# ...                                                                                               ...
# Santa Claus                                         <img src='http://image.tmdb.org/t/p/w185//xurQ...
# The Beast of Yucca Flats                            <img src='http://image.tmdb.org/t/p/w185//cehv...
# ...

# %%
df_best.loc[df_best.Budget >=10].sort_values( by= "ROI", ascending=False)
# Out:
#                                                                                \
# Title
# E.T. the Extra-Terrestrial  <img src='http://image.tmdb.org/t/p/w185//cBfk...
# Star Wars                   <img src='http://image.tmdb.org/t/p/w185//6FfC...
# Pretty Woman                <img src='http://image.tmdb.org/t/p/w185//hMVM...
# The Intouchables            <img src='http://image.tmdb.org/t/p/w185//w7Wx...
# The Empire Strikes Back     <img src='http://image.tmdb.org/t/p/w185//7BuH...
# ...                                                                       ...
# Jesus                       <img src='http://image.tmdb.org/t/p/w185//gICg...
# Security                    <img src='http://image.tmdb.org/t/p/w185//9FN5...
# Sunstroke                   <img src='http://image.tmdb.org/t/p/w185//fRtO...
# Detroit                     <img src='http://image.tmdb.org/t/p/w185//7APL...
# The Visitors: Bastille Day  <img src='http://image.tmdb.org/t/p/w185//kBlm...
#
# ...

# %%
#we should make sure our filter condition values dont have a missing value 
df_best.Budget.fillna(0, inplace=True)
df_best.Votes.fillna(0, inplace=True)

# %%
df_best.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 44691 entries, Toy Story to Queerama
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0                   44467 non-null  object
#  1   Budget          44691 non-null  float64
#  2   Revenue         7385 non-null   float64
#  3   Votes           44691 non-null  float64
#  4   Average Rating  42077 non-null  float64
#  5   Popularity      44691 non-null  float64
#  6   Profit          5371 non-null   float64
#  7   ROI             5371 non-null   float64
# dtypes: float64(7), object(1)
# memory usage: 4.1+ MB

# %% [markdown]
# ## Need to write a function to help analyse the data

# %%
def best_worst(n, by, ascending=False, min_bud=0, min_votes = 0):

    df2 = df_best.loc[(df_best.Budget >= min_bud) & (df_best.Votes >= min_votes), ["", by]]\
        .sort_values(by= by, ascending = ascending).head(n).copy() 
    return HTML(df2.to_html(escape=False))

# here we are taking a subset that only shows rows that have a minimum budget and votes of our choosing, then getting columns for the images and whichever column we want to see data from
    #we then sort by and show only the top

# %% [markdown]
# __Movies Top 5 - Highest Budget__

# %%
best_worst(5, "Budget")
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th></th>
#       <th>Budget</th>
#     </tr>
#     <tr>
#       <th>Title</th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Pirates of the Caribbean: On Stranger Tides</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//keGfSvCmYj7CvdRx36OdVrAEibE.jpg' style='height:100px;'></td>
#       <td>380.00</td>
#     </tr>
#     <tr>
#       <th>Pirates of the Caribbean: At World's End</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//oVh3REsCwJwmrTkZ9OkkeKiAE02.jpg' style='height:100px;'></td>
#       <td>300.00</td>
#     </tr>
#     <tr>
#       <th>Avengers: Age of Ultron</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//4ssDuvEDkSArWEdyBl2X5EHvYKU.jpg' style='height:100px;'></td>
#       <td>280.00</td>
#     </tr>
#     <tr>
#       <th>Superman Returns</th>
# ...

# %% [markdown]
# __Movies Top 5 - Highest Profit__

# %%
best_worst(5, "Profit")
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th></th>
#       <th>Profit</th>
#     </tr>
#     <tr>
#       <th>Title</th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Avatar</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//btnl50ZDJDSCal2NLQIYWw0XxvH.jpg' style='height:100px;'></td>
#       <td>2550.97</td>
#     </tr>
#     <tr>
#       <th>Star Wars: The Force Awakens</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//9rd002JS49RwDW944fF1wjU8iTV.jpg' style='height:100px;'></td>
#       <td>1823.22</td>
#     </tr>
#     <tr>
#       <th>Titanic</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//9xjZS2rlVxm8SFx8kPC3aIGCOYQ.jpg' style='height:100px;'></td>
#       <td>1645.03</td>
#     </tr>
#     <tr>
#       <th>Jurassic World</th>
# ...

# %% [markdown]
# __Movies Top 5 - Lowest Profit__

# %%
best_worst(5, "Profit", ascending=True)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th></th>
#       <th>Profit</th>
#     </tr>
#     <tr>
#       <th>Title</th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>The Lone Ranger</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//b2je2ZybNIzAOL1K1WPbbT6zt2M.jpg' style='height:100px;'></td>
#       <td>-165.71</td>
#     </tr>
#     <tr>
#       <th>The Alamo</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//aZrWYkxCCwSPKp4VjVvn46uHbIX.jpg' style='height:100px;'></td>
#       <td>-119.18</td>
#     </tr>
#     <tr>
#       <th>Mars Needs Moms</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//lOKqLd0ud1wdwaPK5h6bGNZIVLT.jpg' style='height:100px;'></td>
#       <td>-111.01</td>
#     </tr>
#     <tr>
#       <th>Valerian and the City of a Thousand Planets</th>
# ...

# %% [markdown]
# __Movies Top 5 - Highest ROI__

# %%
best_worst(5, "ROI", min_bud=50)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th></th>
#       <th>ROI</th>
#     </tr>
#     <tr>
#       <th>Title</th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Minions</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//tMaGZ2HR8HAFwkx4YRib0CDVfNT.jpg' style='height:100px;'></td>
#       <td>15.63</td>
#     </tr>
#     <tr>
#       <th>Jurassic Park</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//oU7Oq2kFAAlGqbU4VoAE36g4hoI.jpg' style='height:100px;'></td>
#       <td>14.60</td>
#     </tr>
#     <tr>
#       <th>The Twilight Saga: New Moon</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//j5jM5pq78ObAXX1WhTsb115EkLl.jpg' style='height:100px;'></td>
#       <td>14.20</td>
#     </tr>
#     <tr>
#       <th>Deadpool</th>
# ...

# %% [markdown]
# __Movies Top 5 - Lowest ROI__

# %%
best_worst(5, "ROI", ascending=True, min_bud=100)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th></th>
#       <th>ROI</th>
#     </tr>
#     <tr>
#       <th>Title</th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>The Adventures of Pluto Nash</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//96vvhLWWDosS1zRrfQ6XEGAzByL.jpg' style='height:100px;'></td>
#       <td>0.07</td>
#     </tr>
#     <tr>
#       <th>The Alamo</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//aZrWYkxCCwSPKp4VjVvn46uHbIX.jpg' style='height:100px;'></td>
#       <td>0.18</td>
#     </tr>
#     <tr>
#       <th>Live by Night</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//bkd46T4RplawnDjpHoI8mhzTLks.jpg' style='height:100px;'></td>
#       <td>0.21</td>
#     </tr>
#     <tr>
#       <th>Mars Needs Moms</th>
# ...

# %% [markdown]
# __Movies Top 5 - Most Votes__

# %%
best_worst(5, "Votes")
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th></th>
#       <th>Votes</th>
#     </tr>
#     <tr>
#       <th>Title</th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Inception</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//9gk7adHYeDvHkCSEqAvQNLV5Uge.jpg' style='height:100px;'></td>
#       <td>14075.00</td>
#     </tr>
#     <tr>
#       <th>The Dark Knight</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//qJ2tW6WMUDux911r6m7haRef0WH.jpg' style='height:100px;'></td>
#       <td>12269.00</td>
#     </tr>
#     <tr>
#       <th>Avatar</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//btnl50ZDJDSCal2NLQIYWw0XxvH.jpg' style='height:100px;'></td>
#       <td>12114.00</td>
#     </tr>
#     <tr>
#       <th>The Avengers</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//RYMX2wcKCBAr24UyPD7xwmjaTn.jpg' style='height:100px;'></td>
# ...

# %% [markdown]
# __Movies Top 5 - Highest Rating__

# %%
best_worst(5, "Average Rating", min_votes=50)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th></th>
#       <th>Average Rating</th>
#     </tr>
#     <tr>
#       <th>Title</th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Planet Earth II</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//gTvArgUjEUDxYMqJHSwVlrn1Cjk.jpg' style='height:100px;'></td>
#       <td>9.50</td>
#     </tr>
#     <tr>
#       <th>Dilwale Dulhania Le Jayenge</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//2CAL2433ZeIihfX1Hb2139CX0pW.jpg' style='height:100px;'></td>
#       <td>9.10</td>
#     </tr>
#     <tr>
#       <th>Planet Earth</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//koVzjt54bJEVuKTmGC4cExcbE2w.jpg' style='height:100px;'></td>
#       <td>8.80</td>
#     </tr>
#     <tr>
#       <th>Sansho the Bailiff</th>
# ...

# %% [markdown]
# __Movies Top 5 - Lowest Rating__

# %%
best_worst(5, "Average Rating", ascending=True, min_votes=100)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th></th>
#       <th>Average Rating</th>
#     </tr>
#     <tr>
#       <th>Title</th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>House of the Dead</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//5jBIUM0tqq8QwNbY8w1RZdU6uWz.jpg' style='height:100px;'></td>
#       <td>2.80</td>
#     </tr>
#     <tr>
#       <th>Dragonball Evolution</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//23PcKOqNdhKeMFzORzQGn5eC44N.jpg' style='height:100px;'></td>
#       <td>2.90</td>
#     </tr>
#     <tr>
#       <th>Battlefield Earth</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//wXCRuBHdJ5aTFQdsuGJFXNdo79T.jpg' style='height:100px;'></td>
#       <td>3.00</td>
#     </tr>
#     <tr>
#       <th>Disaster Movie</th>
# ...

# %% [markdown]
# ## Most Popular movies

# %%
best_worst(5, "Popularity")
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th></th>
#       <th>Popularity</th>
#     </tr>
#     <tr>
#       <th>Title</th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Minions</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//tMaGZ2HR8HAFwkx4YRib0CDVfNT.jpg' style='height:100px;'></td>
#       <td>547.49</td>
#     </tr>
#     <tr>
#       <th>Wonder Woman</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//gfJGlDaHuWimErCr5Ql0I8x9QSy.jpg' style='height:100px;'></td>
#       <td>294.34</td>
#     </tr>
#     <tr>
#       <th>Beauty and the Beast</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//tWqifoYuwLETmmasnGHO7xBjEtt.jpg' style='height:100px;'></td>
#       <td>287.25</td>
#     </tr>
#     <tr>
#       <th>Baby Driver</th>
# ...

# %% [markdown]
# ## 1. Science Fiction Action Movie with Bruce Willis sort by ratings

# %%
df.genres[0]
# Out:
# 'Animation|Comedy|Family'

# %%
mask_genre = df.genres.str.contains("Action") & df.genres.str.contains("Science Fiction")

mask_genre  #get all the rows in genre that come up as true
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 44686    False
# 44687    False
# 44688    False
# 44689    False
# 44690    False
# Name: genres, Length: 44691, dtype: bool

# %%
df.cast[0]
# Out:
# 'Tom Hanks|Tim Allen|Don Rickles|Jim Varney|Wallace Shawn|John Ratzenberger|Annie Potts|John Morris|Erik von Detten|Laurie Metcalf|R. Lee Ermey|Sarah Freeman|Penn Jillette'

# %%
mask_actor = df.cast.str.contains("Bruce Willis")

mask_actor
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 44686    False
# 44687    False
# 44688    False
# 44689    False
# 44690      NaN
# Name: cast, Length: 44691, dtype: object

# %%
df.loc[mask_actor & mask_genre, ["title", "poster_path", "vote_average"]].sort_values(by = "vote_average", ascending=False)
# Out:
#                        title  \
# 1448       The Fifth Element
# 19218                 Looper
# 1786              Armageddon
# 14135             Surrogates
# 20333  G.I. Joe: Retaliation
# 27619                   Vice
#
#                                              poster_path  vote_average
# 1448   <img src='http://image.tmdb.org/t/p/w185//fPtl...          7.30
# 19218  <img src='http://image.tmdb.org/t/p/w185//sNjL...          6.60
# 1786   <img src='http://image.tmdb.org/t/p/w185//fMtO...          6.50
# 14135  <img src='http://image.tmdb.org/t/p/w185//v3Z0...          5.90
# 20333  <img src='http://image.tmdb.org/t/p/w185//3rWI...          5.40
# 27619  <img src='http://image.tmdb.org/t/p/w185//nPqN...          4.10

# %%
bruce = df.loc[mask_actor & mask_genre, ["title", "poster_path", "vote_average"]].sort_values(by = "vote_average", ascending=False).set_index("title")

HTML(bruce.to_html(escape=False))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>poster_path</th>
#       <th>vote_average</th>
#     </tr>
#     <tr>
#       <th>title</th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>The Fifth Element</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//fPtlCO1yQtnoLHOwKtWz7db6RGU.jpg' style='height:100px;'></td>
#       <td>7.30</td>
#     </tr>
#     <tr>
#       <th>Looper</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//sNjL6SqErDBE8OUZlrDLkexfsCj.jpg' style='height:100px;'></td>
#       <td>6.60</td>
#     </tr>
#     <tr>
#       <th>Armageddon</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//fMtOCd0EAdAzKtGLQiHjSUvbdNc.jpg' style='height:100px;'></td>
#       <td>6.50</td>
#     </tr>
#     <tr>
#       <th>Surrogates</th>
# ...

# %% [markdown]
# ## 2- find any movies directed by Quentin Terantino with Uma Thurman in the cast and group by ratings

# %%
m_actor = df.cast.str.contains("Uma Thurman")

m_actor
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 44686    False
# 44687    False
# 44688    False
# 44689    False
# 44690      NaN
# Name: cast, Length: 44691, dtype: object

# %%
m_director =df.director.str.contains("Quentin Tarantino")

m_director
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 44686    False
# 44687    False
# 44688    False
# 44689    False
# 44690    False
# Name: director, Length: 44691, dtype: object

# %%
df.loc[m_actor & m_director, ["title", "poster_path", "runtime"]].sort_values(by = "runtime", ascending=True).set_index("title")
# Out:
#                                                          poster_path  runtime
# title
# Kill Bill: Vol. 1  <img src='http://image.tmdb.org/t/p/w185//v7Ta...   111.00
# Kill Bill: Vol. 2  <img src='http://image.tmdb.org/t/p/w185//2yhg...   136.00
# Pulp Fiction       <img src='http://image.tmdb.org/t/p/w185//d5iI...   154.00

# %%
uma = df.loc[m_actor & m_director, ["title", "poster_path", "runtime"]].sort_values(by = "runtime", ascending=True).set_index("title")

HTML(uma.to_html(escape=False))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>poster_path</th>
#       <th>runtime</th>
#     </tr>
#     <tr>
#       <th>title</th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Kill Bill: Vol. 1</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//v7TaX8kXMXs5yFFGR41guUDNcnB.jpg' style='height:100px;'></td>
#       <td>111.00</td>
#     </tr>
#     <tr>
#       <th>Kill Bill: Vol. 2</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//2yhg0mZQMhDyvUQ4rG1IZ4oIA8L.jpg' style='height:100px;'></td>
#       <td>136.00</td>
#     </tr>
#     <tr>
#       <th>Pulp Fiction</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//d5iIlFn5s0ImszYzBPb8JPIfbXD.jpg' style='height:100px;'></td>
#       <td>154.00</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## 3- Most Successful Pixar Studio Movies between 2010 and 2015, sorted by revenue

# %%
df.production_companies.str.contains("Pixar")
# Out:
# 0         True
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 44686      NaN
# 44687    False
# 44688    False
# 44689    False
# 44690      NaN
# Name: production_companies, Length: 44691, dtype: object

# %%
m_studio = df.production_companies.str.contains("Pixar").fillna(False)

m_studio
# Out:
# 0         True
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 44686    False
# 44687    False
# 44688    False
# 44689    False
# 44690    False
# Name: production_companies, Length: 44691, dtype: bool

# %%
m_date = df.release_date.between("2010-01-01", "2015-12-31")

m_date
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 44686    False
# 44687     True
# 44688    False
# 44689    False
# 44690    False
# Name: release_date, Length: 44691, dtype: bool

# %%
pixar = df.loc[m_studio & m_date, ["title", "poster_path", "release_date", "revenue_musd"]].sort_values(by= "revenue_musd", ascending=False).set_index("title")

HTML(pixar.to_html(escape=False))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>poster_path</th>
#       <th>release_date</th>
#       <th>revenue_musd</th>
#     </tr>
#     <tr>
#       <th>title</th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Toy Story 3</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//amY0NH1ksd9xJ9boXAMmods6U0D.jpg' style='height:100px;'></td>
#       <td>2010-06-16</td>
#       <td>1066.97</td>
#     </tr>
#     <tr>
#       <th>Inside Out</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//lRHE0vzf3oYJrhbsHXjIkF4Tl5A.jpg' style='height:100px;'></td>
#       <td>2015-06-09</td>
#       <td>857.61</td>
#     </tr>
#     <tr>
#       <th>Monsters University</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//tyHHjZEzJutWggujN1KP0a1jfLX.jpg' style='height:100px;'></td>
#       <td>2013-06-20</td>
#       <td>743.56</td>
#     </tr>
# ...

# %% [markdown]
# ## Search 4: Action or Thriller Movie with original language English and minimum Rating of 7.5

# %%
m_genre = df.genres.str.contains("Action") | df.genres.str.contains("Thriller")

m_genre
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 44686    False
# 44687    False
# 44688     True
# 44689    False
# 44690    False
# Name: genres, Length: 44691, dtype: bool

# %%
m_lang = df.original_language.str.contains("en") 

m_lang
# Out:
# 0         True
# 1         True
# 2         True
# 3         True
# 4         True
#          ...
# 44686    False
# 44687    False
# 44688     True
# 44689     True
# 44690     True
# Name: original_language, Length: 44691, dtype: object

# %%
eng_lang = df.loc[m_lang & m_genre & (df.vote_average >= 7.5), ["title", "poster_path", "release_date", "vote_average"]] \
.sort_values(by="release_date", ascending=False).set_index("title").head(20)

# %%
HTML(eng_lang.to_html(escape=False))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>poster_path</th>
#       <th>release_date</th>
#       <th>vote_average</th>
#     </tr>
#     <tr>
#       <th>title</th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Descendants 2</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//8BNyZlBk4Hs92z6UrvFDjvx3yMb.jpg' style='height:100px;'></td>
#       <td>2017-07-21</td>
#       <td>7.50</td>
#     </tr>
#     <tr>
#       <th>Dunkirk</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//ebSnODDg9lbsMIaWg2uAbjn7TO5.jpg' style='height:100px;'></td>
#       <td>2017-07-19</td>
#       <td>7.50</td>
#     </tr>
#     <tr>
#       <th>The Book of Henry</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//suLFg4UjvM5BoDipg2Wu3gZ802T.jpg' style='height:100px;'></td>
#       <td>2017-06-16</td>
#       <td>7.60</td>
#     </tr>
#     <tr>
# ...

# %%
df
# Out:
#            id                        title  \
# 0         862                    Toy Story
# 1        8844                      Jumanji
# 2       15602             Grumpier Old Men
# 3       31357            Waiting to Exhale
# 4       11862  Father of the Bride Part II
# ...       ...                          ...
# 44686  439050                       Subdue
# 44687  111109          Century of Birthing
# 44688   67758                     Betrayal
# 44689  227506             Satan Triumphant
# 44690  461257                     Queerama
#
#                                                  tagline release_date  \
# 0                                                    NaN   1995-10-30
# 1              Roll the dice and unleash the excitement!   1995-12-15
# 2      Still Yelling. Still Fighting. Still Ready for...   1995-12-22
# 3      Friends are the people who let you be yourself...   1995-12-22
# 4      Just When His World Is Back To Normal... He's ...   1995-02-10
# ...

# %% [markdown]
# ## lets see if movies in franchises are more successful

# %%
collection = df[df.belongs_to_collection.notnull()]

collection
# Out:
#            id                                  title  \
# 0         862                              Toy Story
# 2       15602                       Grumpier Old Men
# 4       11862            Father of the Bride Part II
# 9         710                              GoldenEye
# 12      21032                                  Balto
# ...       ...                                    ...
# 44582   24568             Carry On Follow That Camel
# 44585   19307                       Carry On Camping
# 44596   21251                       Carry On England
# 44598  460135  LEGO DC Super Hero Girls: Brain Drain
# 44609  182030                        The Twin Swords
#
#                                                  tagline release_date  \
# 0                                                    NaN   1995-10-30
# 2      Still Yelling. Still Fighting. Still Ready for...   1995-12-22
# 4      Just When His World Is Back To Normal... He's ...   1995-02-10
# ...

# %%
no_collection = df[df.belongs_to_collection.isnull()]

no_collection
# Out:
#            id                title  \
# 1        8844              Jumanji
# 3       31357    Waiting to Exhale
# 5         949                 Heat
# 6       11860              Sabrina
# 7       45325         Tom and Huck
# ...       ...                  ...
# 44686  439050               Subdue
# 44687  111109  Century of Birthing
# 44688   67758             Betrayal
# 44689  227506     Satan Triumphant
# 44690  461257             Queerama
#
#                                                  tagline release_date  \
# 1              Roll the dice and unleash the excitement!   1995-12-15
# 3      Friends are the people who let you be yourself...   1995-12-22
# 5                               A Los Angeles Crime Saga   1995-12-15
# 6      You are cordially invited to the most surprisi...   1995-12-15
# 7                                 The Original Bad Boys.   1995-12-22
# ...                                                  ...          ...
# ...

# %%
collection.belongs_to_collection
# Out:
# 0                  Toy Story Collection
# 2             Grumpy Old Men Collection
# 4        Father of the Bride Collection
# 9                 James Bond Collection
# 12                     Balto Collection
#                       ...
# 44582           The Carry On Collection
# 44585           The Carry On Collection
# 44596           The Carry On Collection
# 44598    DC Super Hero Girls Collection
# 44609              Red Lotus Collection
# Name: belongs_to_collection, Length: 4463, dtype: object

# %% [markdown]
# __Franchise v non-franchise movies: Average Revenue__

# %%
df["Franchise"] = df.belongs_to_collection.notna()

df
# Out:
#            id                        title  \
# 0         862                    Toy Story
# 1        8844                      Jumanji
# 2       15602             Grumpier Old Men
# 3       31357            Waiting to Exhale
# 4       11862  Father of the Bride Part II
# ...       ...                          ...
# 44686  439050                       Subdue
# 44687  111109          Century of Birthing
# 44688   67758                     Betrayal
# 44689  227506             Satan Triumphant
# 44690  461257                     Queerama
#
#                                                  tagline release_date  \
# 0                                                    NaN   1995-10-30
# 1              Roll the dice and unleash the excitement!   1995-12-15
# 2      Still Yelling. Still Fighting. Still Ready for...   1995-12-22
# 3      Friends are the people who let you be yourself...   1995-12-22
# 4      Just When His World Is Back To Normal... He's ...   1995-02-10
# ...

# %%
df["profit_musd"] = df["revenue_musd"].sub(df["budget_musd"])  # profit 
#df_best["ROI"] = df_best["revenue_musd"] /df_best[df_best.budget_musd >= 10]["budget_musd"] #roi
df["ROI"] = df["revenue_musd"]/(df["budget_musd"])

# %%
df.groupby("Franchise") ["revenue_musd"].mean()
# Out:
# Franchise
# False    44.74
# True    165.71
# Name: revenue_musd, dtype: float64

# %% [markdown]
# __Franchise v non franchise (median)__

# %%
df.groupby("Franchise") ["ROI"].median()
# Out:
# Franchise
# False   1.62
# True    3.71
# Name: ROI, dtype: float64

# %% [markdown]
# __Franchise v non franchise: Average Budget__

# %%
df.groupby("Franchise") ["budget_musd"].mean()
# Out:
# Franchise
# False   18.05
# True    38.32
# Name: budget_musd, dtype: float64

# %% [markdown]
# __Franchise v non franchise: Average Popularity__

# %%
df.groupby("Franchise") ["popularity"].mean()
# Out:
# Franchise
# False   2.59
# True    6.25
# Name: popularity, dtype: float64

# %% [markdown]
# __Franchise v non franchise: Average Rating__

# %%
df.groupby("Franchise") ["vote_average"].mean()
# Out:
# Franchise
# False   6.01
# True    5.96
# Name: vote_average, dtype: float64

# %% [markdown]
# ## most successful Franchises

# %% [markdown]
# ##total number in franchises

# %%
df.belongs_to_collection.value_counts()
# Out:
# belongs_to_collection
# The Bowery Boys                  29
# Totò Collection                  27
# Zatôichi: The Blind Swordsman    26
# James Bond Collection            26
# The Carry On Collection          25
#                                  ..
# Salt and Pepper Collection        1
# Deadpool Collection               1
# Ant-Man Collection                1
# Elvira Collection                 1
# Red Lotus Collection              1
# Name: count, Length: 1691, dtype: int64

# %%
franchises = df.groupby("belongs_to_collection").agg({"title": "count", "budget_musd": ["sum", "mean"], "revenue_musd": ["sum", "mean"],
                                                     "vote_average": "mean", "vote_count" : "mean"})

# %%
franchises
# Out:
#                                      title budget_musd       revenue_musd  \
#                                      count         sum  mean          sum
# belongs_to_collection
# ... Has Fallen Collection                2      130.00 65.00       366.78
# 00 Schneider Filmreihe                   1        0.00   NaN         0.00
# 08/15 Collection                         1        0.00   NaN         0.00
# 100 Girls Collection                     2        0.00   NaN         0.00
# 101 Dalmatians (Animated) Collection     2        4.00  4.00       215.88
# ...                                    ...         ...   ...          ...
# Сказки Чуковского                        1        0.00   NaN         0.00
# Чебурашка и крокодил Гена                1        0.00   NaN         0.00
# Что Творят мужчины! (Коллекция)          2        2.00  2.00         0.00
# 男はつらいよ シリーズ                              3        0.00   NaN         0.00
# ...

# %%
franchises.nlargest(5, ("title", "count"))
# Out:
#                               title budget_musd       revenue_musd         \
#                               count         sum  mean          sum   mean
# belongs_to_collection
# The Bowery Boys                  29        0.00   NaN         0.00    NaN
# Totò Collection                  27        0.00   NaN         0.00    NaN
# James Bond Collection            26     1539.65 59.22      7106.97 273.35
# Zatôichi: The Blind Swordsman    26        0.00   NaN         0.00    NaN
# The Carry On Collection          25        0.00   NaN         0.00    NaN
#
#                               vote_average vote_count
#                                       mean       mean
# belongs_to_collection
# The Bowery Boys                       6.67       0.72
# Totò Collection                       6.84      18.04
# James Bond Collection                 6.34    1284.31
# Zatôichi: The Blind Swordsman         6.40      11.19
# The Carry On Collection               6.17      21.04

# %%
franchises["budget_musd"].nlargest(5, "sum"), franchises["budget_musd"].nlargest(5, "mean")
# Out:
# (                                        sum   mean
#  belongs_to_collection
#  James Bond Collection               1539.65  59.22
#  Harry Potter Collection             1280.00 160.00
#  Pirates of the Caribbean Collection 1250.00 250.00
#  The Fast and the Furious Collection 1009.00 126.12
#  X-Men Collection                     983.00 163.83,
#                                          sum   mean
#  belongs_to_collection
#  Tangled Collection                   260.00 260.00
#  Pirates of the Caribbean Collection 1250.00 250.00
#  The Avengers Collection              500.00 250.00
#  The Hobbit Collection                750.00 250.00
#  Man of Steel Collection              475.00 237.50)

# %%
franchises["revenue_musd"].nlargest(5, "sum"), franchises["revenue_musd"].nlargest(5, "mean")
# Out:
# (                                        sum   mean
#  belongs_to_collection
#  Harry Potter Collection             7707.37 963.42
#  Star Wars Collection                7434.49 929.31
#  James Bond Collection               7106.97 273.35
#  The Fast and the Furious Collection 5125.10 640.64
#  Pirates of the Caribbean Collection 4521.58 904.32,
#                              sum    mean
#  belongs_to_collection
#  Avatar Collection       2787.97 2787.97
#  The Avengers Collection 2924.96 1462.48
#  Frozen Collection       1274.22 1274.22
#  Finding Nemo Collection 1968.91  984.45
#  The Hobbit Collection   2935.52  978.51)

# %%
franchises[franchises["vote_count", "mean"] >= 1000].nlargest(5,("vote_average", "mean"))
# Out:
#                                  title budget_musd        revenue_musd         \
#                                  count         sum   mean          sum   mean
# belongs_to_collection
# The Lord of the Rings Collection     3      266.00  88.67      2916.54 972.18
# The Godfather Collection             3       73.00  24.33       429.38 143.13
# Blade Runner Collection              1       28.00  28.00        33.14  33.14
# The Man With No Name Collection      3        2.00   0.67        35.50  11.83
# The Dark Knight Collection           3      585.00 195.00      2463.72 821.24
#
#                                  vote_average vote_count
#                                          mean       mean
# belongs_to_collection
# The Lord of the Rings Collection         8.03    8253.00
# The Godfather Collection                 7.97    3677.00
# Blade Runner Collection                  7.90    3833.00
# The Man With No Name Collection          7.83    1422.67
# ...

# %% [markdown]
# ## lets work on the directors now

# %%
df.director
# Out:
# 0           John Lasseter
# 1            Joe Johnston
# 2           Howard Deutch
# 3         Forest Whitaker
# 4           Charles Shyer
#                ...
# 44686    Hamid Nematollah
# 44687            Lav Diaz
# 44688      Mark L. Lester
# 44689    Yakov Protazanov
# 44690       Daisy Asquith
# Name: director, Length: 44691, dtype: object

# %%
df.director.value_counts()
# Out:
# director
# John Ford           66
# Michael Curtiz      65
# Werner Herzog       54
# Alfred Hitchcock    53
# Georges Méliès      49
#                     ..
# Jason Osder          1
# John Alan Simon      1
# Jennifer Kent        1
# Hiroshi Ando         1
# Daisy Asquith        1
# Name: count, Length: 17349, dtype: int64

# %%
directors = df.groupby("director").agg({"title": "count", "revenue_musd": 'sum', "vote_average": ["mean", "sum"], "vote_count": "sum"})

directors
# Out:
#                     title revenue_musd vote_average       vote_count
#                     count          sum         mean   sum        sum
# director
#  Dale Trevillion\t      2         0.00         4.00  4.00       4.00
#  Davide Manuli          1         0.00         6.90  6.90      10.00
#  E.W. Swackhamer        1         0.00         5.90  5.90       5.00
#  Vitaliy Vorobyov       1         0.00         5.50  5.50       3.00
#  Yeon Sang-Ho           4         2.13         6.60 26.40    1039.00
# ...                   ...          ...          ...   ...        ...
# Ярополк Лапшин          1         0.00        10.00 10.00       1.00
# پیمان معادی             1         0.00         6.00  6.00       2.00
# 塩谷 直義                   1         0.00         7.20  7.20      40.00
# 杰森·莫玛                   1         0.00         5.80  5.80      28.00
# 진모영                     1         0.00         6.00  6.00       6.00
#
# [17349 rows x 5 columns]

# %%
plt.figure(figsize=(12,8))
df.director.value_counts().head(20).plot(kind="bar", fontsize=15)
plt.title("Most active directors", fontsize=30)
plt.ylabel("Number of movies", fontsize=15)
plt.xlabel("names of directors", fontsize=15)
plt.show()

# %%
directors.nlargest(5, ("title", "count"))
# Out:
#                  title revenue_musd vote_average        vote_count
#                  count          sum         mean    sum       mean
# director
# John Ford           66        85.17         6.38 421.20      33.48
# Michael Curtiz      65        37.82         6.00 341.90      38.09
# Werner Herzog       54        24.57         6.81 367.50      46.59
# Alfred Hitchcock    53       250.11         6.64 351.90     240.98
# Georges Méliès      49         0.00         5.93 290.80      16.86

# %%
df.groupby("director").revenue_musd.sum().nlargest(20)
# Out:
# director
# Steven Spielberg    9256.62
# Peter Jackson       6528.24
# Michael Bay         6437.47
# James Cameron       5900.61
# David Yates         5334.56
# Christopher Nolan   4747.41
# Robert Zemeckis     4138.23
# Tim Burton          4032.92
# Ridley Scott        3917.53
# Chris Columbus      3866.84
# Roland Emmerich     3798.40
# Ron Howard          3714.15
# J.J. Abrams         3579.22
# Gore Verbinski      3575.34
# George Lucas        3341.55
# Sam Raimi           3193.79
# Francis Lawrence    3183.34
# Clint Eastwood      3100.68
# Bill Condon         3017.30
# Joss Whedon         2963.83
# Name: revenue_musd, dtype: float64

# %%
plt.figure(figsize=(12,8))
df.groupby("director").revenue_musd.sum().nlargest(20).plot(kind="bar", fontsize=15)
plt.title("Total Revenue", fontsize=30)
plt.ylabel("Revenue in Musd", fontsize=15)
plt.xlabel("names of directors", fontsize=15)
plt.show()

# %%
directors
# Out:
#                     title revenue_musd vote_average       vote_count
#                     count          sum         mean   sum       mean
# director
#  Dale Trevillion\t      2         0.00         4.00  4.00       2.00
#  Davide Manuli          1         0.00         6.90  6.90      10.00
#  E.W. Swackhamer        1         0.00         5.90  5.90       5.00
#  Vitaliy Vorobyov       1         0.00         5.50  5.50       3.00
#  Yeon Sang-Ho           4         2.13         6.60 26.40     259.75
# ...                   ...          ...          ...   ...        ...
# Ярополк Лапшин          1         0.00        10.00 10.00       1.00
# پیمان معادی             1         0.00         6.00  6.00       2.00
# 塩谷 直義                   1         0.00         7.20  7.20      40.00
# 杰森·莫玛                   1         0.00         5.80  5.80      28.00
# 진모영                     1         0.00         6.00  6.00       6.00
#
# [17349 rows x 5 columns]

# %%
directors[(directors["vote_count", "sum"] >= 10000) & (directors["title", "count"] >= 10)].nlargest(20, ("vote_average", "mean"))
# Out:
#                   title revenue_musd vote_average        vote_count
#                   count          sum         mean    sum        sum
# director
# Hayao Miyazaki       14       995.90         7.70 107.80   14700.00
# Christopher Nolan    11      4747.41         7.62  83.80   67344.00
# Quentin Tarantino    10      1526.67         7.49  74.90   45910.00
# Wes Anderson         10       437.62         7.37  73.70   11743.00
# David Fincher        10      2139.35         7.35  73.50   37588.00
# Martin Scorsese      39      1990.98         7.22 274.30   35541.00
# Peter Jackson        13      6528.24         7.14  92.80   47571.00
# Joel Coen            17      1054.64         7.02 119.40   18139.00
# James Cameron        11      5900.61         6.93  76.20   33736.00
# Stanley Kubrick      16       446.45         6.91 110.60   18214.00
# James Mangold        10      1685.75         6.90  69.00   16607.00
# Steven Spielberg     33      9256.62         6.89 227.50   62266.00
# ...
